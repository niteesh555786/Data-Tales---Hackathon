# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Importing Dataset

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL     ...      UTILITY_AVAIL  STREET  \
# 0         1.0       3  AbNormal        Yes     ...             AllPub   Paved
# 1         1.0       5  AbNormal         No     ...             AllPub  Gravel
# 2         1.0       3  AbNormal        Yes     ...                ELO  Gravel
# 3         2.0       5    Family         No     ...            NoSewr    Paved
# 4         1.0       3  AbNormal        Yes     ...             AllPub  Gravel
#
#   MZZONE QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  \
# ...

# %%
df.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL        REG_FEE  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  376938.330708
# std       0.891972     0.897834     0.887266     0.527223  143070.662010
# ...

# %%
df.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DATE_SALE         object
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# DATE_BUILD        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# REG_FEE            int64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
df.columns[df.dtypes == float]
# Out:
# Index(['N_BEDROOM', 'N_BATHROOM', 'QS_ROOMS', 'QS_BATHROOM', 'QS_BEDROOM',
#        'QS_OVERALL'],
#       dtype='object')

# %% [markdown]
# ## Analysing Features

# %% [markdown]
# ### 1. Analysing Area

# %%
print( np.unique(df['AREA'] ))
# Out:
# ['Adyar' 'Adyr' 'Ana Nagar' 'Ann Nagar' 'Anna Nagar' 'Chormpet' 'Chrmpet'
#  'Chrompet' 'Chrompt' 'KK Nagar' 'KKNagar' 'Karapakam' 'Karapakkam'
#  'T Nagar' 'TNagar' 'Velachery' 'Velchery']

# %%
df['AREA'].value_counts()
# Out:
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chormpet         6
# Chrmpet          6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# KKNagar          1
# Adyr             1
# Name: AREA, dtype: int64

# %% [markdown]
# ### 2. Interior Sq. Feet

# %%
df['INT_SQFT'].head()
# Out:
# 0    1004
# 1    1986
# 2     909
# 3    1855
# 4    1226
# Name: INT_SQFT, dtype: int64

# %%
df['INT_SQFT'].hist()

# %%
df['INT_SQFT'].plot(kind='density')

# %% [markdown]
# ### 3. DATE_SALE

# %% [markdown]
# *Will be one of the important feature because it will denote the trend*

# %%
df['DATE_SALE'].head()
# Out:
# 0    04-05-2011
# 1    19-12-2006
# 2    04-02-2012
# 3    13-03-2010
# 4    05-10-2009
# Name: DATE_SALE, dtype: object

# %% [markdown]
# ### SALES_PRICE

# %%
#descriptive statistics summary
df['SALES_PRICE'].describe()
# Out:
# count    7.109000e+03
# mean     1.089491e+07
# std      3.768603e+06
# min      2.156875e+06
# 25%      8.272100e+06
# 50%      1.033505e+07
# 75%      1.299390e+07
# max      2.366734e+07
# Name: SALES_PRICE, dtype: float64

# %%
#histogram
sns.distplot(df['SALES_PRICE']);

# %%
#skewness and kurtosis
print("Skewness: %f" % df['SALES_PRICE'].skew())
print("Kurtosis: %f" % df['SALES_PRICE'].kurt())
# Out:
# Skewness: 0.773343
# Kurtosis: 0.588129

# %% [markdown]
# ## Relationship with numerical variables

# %% [markdown]
# ### 1. INT_SQFT

# %%
#scatter plot 
var = 'INT_SQFT'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
data.plot.scatter(x=var, y='SALES_PRICE');

# %% [markdown]
# ### 2. DIST_MAINROAD

# %%
#scatter plot
var='DIST_MAINROAD'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var, y='SALES_PRICE')

# %% [markdown]
# ### 3. N_BEDROOM

# %%
var='N_BEDROOM'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 4. N_BATHROOM

# %%
var='N_BATHROOM'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 5. N_ROOM

# %%
var='N_ROOM'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 6. QS_ROOMS

# %%
var='QS_ROOMS'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 7. QS_BATHROOM

# %%
var='QS_BATHROOM'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 8. QS_BEDROOM

# %%
var='QS_BEDROOM'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 9. QS_OVERALL

# %%
var='QS_OVERALL'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 10. REG_FEE

# %%
var='REG_FEE'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ### 11. COMMIS

# %%
var='COMMIS'
data=pd.concat([df['SALES_PRICE'],df[var]],axis=1)
data.plot.scatter(x=var,y='SALES_PRICE')

# %% [markdown]
# ## Relationship with categorical features

# %%
"""AREA              object
SALE_COND         object
PARK_FACIL        object
DATE_BUILD        object
BUILDTYPE         object
UTILITY_AVAIL     object
STREET            object
MZZONE            object"""
# Out:
# 'AREA              object\nSALE_COND         object\nPARK_FACIL        object\nDATE_BUILD        object\nBUILDTYPE         object\nUTILITY_AVAIL     object\nSTREET            object\nMZZONE            object'

# %% [markdown]
# ### 1. AREA

# %%
df['AREA'].value_counts()
# Out:
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chormpet         6
# Chrmpet          6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# KKNagar          1
# Adyr             1
# Name: AREA, dtype: int64

# %% [markdown]
# * As we can see Chrompet, Chrompt, Chrmpet and Chrompet are marked as different.
# * Similarly Anna Nagar, Ana Nagar and Ann Nagar.
# * Similarly KK Nagar and KKNagar
# * Similarly T Nagar and TNagar
# * Similarly Adyar and Adyr.
# * Similarly Velachery and Velechery.
# * Similarly Karapakkam and Karapakm

# %%
for i in range(len(df['AREA'])):
    if (df['AREA'][i]=='Chrompt') or (df['AREA'][i]=='Chrmpet') or (df['AREA'][i]=='Chrompet') or (df['AREA'][i]=='Chormpet'):
        df.set_value(i,'AREA','Chrompet')
    if (df['AREA'][i]=='Ana Nagar') or (df['AREA'][i]=='Ann Nagar'):
        df.set_value(i,'AREA','Anna Nagar')
    if (df['AREA'][i]=='TNagar'):
        df.set_value(i,'AREA','T Nagar')
    if (df['AREA'][i]=='Adyr'):
        df.set_value(i,'AREA','Adyar')
    if (df['AREA'][i]=='KKNagar'):
        df.set_value(i,'AREA','KK Nagar')
    if (df['AREA'][i]=='Velechery') or (df['AREA'][i]=='Velchery'):
        df.set_value(i,'AREA','Velachery')
    if (df['AREA'][i]=='Karapakm') or (df['AREA'][i]=='Karapakam'):
        df.set_value(i,'AREA','Karapakkam')

# %%
df['AREA'].value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: AREA, dtype: int64

# %%
#box plot 
var = 'AREA'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SALES_PRICE", data=data)
fig.axis(ymin=0, ymax=2.5e7);

# %% [markdown]
# ### 2. SALE_COND

# %%
df['SALE_COND'].value_counts()
# Out:
# AdjLand        1433
# Partial        1429
# Normal Sale    1423
# AbNormal       1406
# Family         1403
# Adj Land          6
# Ab Normal         5
# Partiall          3
# PartiaLl          1
# Name: SALE_COND, dtype: int64

# %%
for i in range(len(df)):
    if (df['SALE_COND'][i]=='Adj Land'):
        df.set_value(i,'SALE_COND','AdjLand')
    if (df['SALE_COND'][i]=='Ab Normal'):
        df.set_value(i,'SALE_COND','AbNormal') 
    if (df['SALE_COND'][i]=='Partiall') or (df['SALE_COND'][i]=='PartiaLl'):
        df.set_value(i,'SALE_COND','Partial')

# %%
#box plot 
var = 'SALE_COND'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SALES_PRICE", data=data)
fig.axis(ymin=0, ymax=2.5e7);

# %% [markdown]
# ### 3. PARK_FACIL

# %%
df['PARK_FACIL'].value_counts()
# Out:
# Yes    3587
# No     3520
# Noo       2
# Name: PARK_FACIL, dtype: int64

# %%
for i in range(len(df)):
    if (df['PARK_FACIL'][i]=='Noo'):
        df.set_value(i,'PARK_FACIL','No')

# %%
#box plot 
var = 'PARK_FACIL'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SALES_PRICE", data=data)
fig.axis(ymin=0, ymax=2.5e7);

# %% [markdown]
# ### 4. BUILDTYPE

# %%
df['BUILDTYPE'].value_counts()
# Out:
# House         2444
# Commercial    2325
# Others        2310
# Other           26
# Comercial        4
# Name: BUILDTYPE, dtype: int64

# %%
for i in range(len(df)):
    if (df['BUILDTYPE'][i]=='Other'):
        df.set_value(i,'BUILDTYPE','Others')
    if (df['BUILDTYPE'][i]=='Comercial'):
        df.set_value(i,'BUILDTYPE','Commercial')

# %%
#box plot 
var = 'BUILDTYPE'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SALES_PRICE", data=data)
fig.axis(ymin=0, ymax=2.5e7);

# %% [markdown]
# ### 5. UTILITY_AVAIL

# %%
df['UTILITY_AVAIL'].value_counts()
# Out:
# AllPub     1886
# NoSeWa     1871
# NoSewr     1829
# ELO        1522
# All Pub       1
# Name: UTILITY_AVAIL, dtype: int64

# %%
for i in range(len(df)):
    if (df['UTILITY_AVAIL'][i]=='All Pub'):
        df.set_value(i,'UTILITY_AVAIL','AllPub')

# %%
#box plot 
var = 'UTILITY_AVAIL'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SALES_PRICE", data=data)
fig.axis(ymin=0, ymax=2.5e7);

# %% [markdown]
# ### 6. STREET

# %%
df['STREET'].value_counts()
# Out:
# Paved        2560
# Gravel       2520
# No Access    2010
# Pavd           12
# NoAccess        7
# Name: STREET, dtype: int64

# %%
for i in range(len(df)):
    if (df['STREET'][i]=='Pavd'):
        df.set_value(i,'STREET','Paved')
    if (df['STREET'][i]=='NoAccess'):
        df.set_value(i,'STREET','No Access')

# %%
#box plot 
var = 'STREET'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SALES_PRICE", data=data)
fig.axis(ymin=0, ymax=2.5e7);

# %% [markdown]
# ### 7. MZZONE

# %%
#box plot 
var = 'MZZONE'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SALES_PRICE", data=data)
fig.axis(ymin=0, ymax=2.5e7);

# %% [markdown]
# # Correlation matrix (heatmap style)

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SALES_PRICE')['SALES_PRICE'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
corr = df.corr()
print(corr['SALES_PRICE'].sort_values(ascending=False))#top 15 values
print("=====================================================")
print(corr['SALES_PRICE'].sort_values(ascending=False)[-5:])#last 5
# Out:
# SALES_PRICE      1.000000
# REG_FEE          0.878148
# COMMIS           0.626275
# INT_SQFT         0.612125
# N_ROOM           0.602760
# N_BEDROOM        0.330999
# N_BATHROOM       0.108884
# QS_ROOMS         0.021967
# QS_OVERALL       0.020556
# QS_BEDROOM       0.018804
# DIST_MAINROAD    0.018783
# QS_BATHROOM     -0.011377
# Name: SALES_PRICE, dtype: float64
# ...
# QS_ROOMS         0.021967
# QS_OVERALL       0.020556
# QS_BEDROOM       0.018804
# DIST_MAINROAD    0.018783
# QS_BATHROOM     -0.011377
# Name: SALES_PRICE, dtype: float64

# %% [markdown]
# ## Scatter plots between 'SalePrice' and correlated variables (move like Jagger style)

# %%
#scatterplot
sns.set()
cols = ['SALES_PRICE', 'REG_FEE', 'COMMIS', 'INT_SQFT', 'N_ROOM']
sns.pairplot(df[cols], size = 2.5)
plt.show();

# %% [markdown]
# # Missing data

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(5)
# Out:
#              Total   Percent
# QS_OVERALL      48  0.006752
# N_BATHROOM       5  0.000703
# N_BEDROOM        1  0.000141
# SALES_PRICE      0  0.000000
# PARK_FACIL       0  0.000000

# %%
#df=df.dropna()

# %%
df.fillna(df.mean(), inplace=True);

# %% [markdown]
# # Out liars

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# *Standardizing*
# * 'SALES_PRICE'
# * 'REG_FEE'
# * 'COMMIS'
# * 'INT_SQFT'
# * 'N_ROOM'

# %% [markdown]
# #### 1.'SALES_PRICE'

# %%
df['SALES_PRICE'].describe()
# Out:
# count    7.109000e+03
# mean     1.089491e+07
# std      3.768603e+06
# min      2.156875e+06
# 25%      8.272100e+06
# 50%      1.033505e+07
# 75%      1.299390e+07
# max      2.366734e+07
# Name: SALES_PRICE, dtype: float64

# %%
#standardizing data
from sklearn.preprocessing import StandardScaler
sc_salePrice=StandardScaler()
saleprice_scaled = sc_salePrice.fit_transform(df['SALES_PRICE'][:,np.newaxis]);
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-2.31880307]
#  [-2.23401769]
#  [-2.19053036]
#  [-2.14886743]
#  [-2.11105236]
#  [-2.09496436]
#  [-2.09473217]
#  [-2.0914814 ]
#  [-2.08716915]
#  [-2.07346948]]
#
# outer range (high) of the distribution:
# [[ 3.16697152]
#  [ 3.17327669]
#  [ 3.19015681]
#  [ 3.19068754]
#  [ 3.21589759]
#  [ 3.27801781]
#  [ 3.29378338]
#  [ 3.29579488]
#  [ 3.32054849]
#  [ 3.38940643]]
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# #### 2. 'REG_FEE'

# %%
df['REG_FEE'].describe()
# Out:
# count      7109.000000
# mean     376938.330708
# std      143070.662010
# min       71177.000000
# 25%      272406.000000
# 50%      349486.000000
# 75%      451562.000000
# max      983922.000000
# Name: REG_FEE, dtype: float64

# %%
#standardizing data
from sklearn.preprocessing import StandardScaler
sc_regFee=StandardScaler()
saleprice_scaled = sc_regFee.fit_transform(df['REG_FEE'][:,np.newaxis]);
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-2.13728541]
#  [-1.96518351]
#  [-1.90835445]
#  [-1.89061372]
#  [-1.8563625 ]
#  [-1.85409772]
#  [-1.84522036]
#  [-1.83963532]
#  [-1.83787383]
#  [-1.83648281]]
#
# outer range (high) of the distribution:
# [[ 3.87448168]
#  [ 3.910061  ]
#  [ 3.94150921]
#  [ 3.94677971]
#  [ 3.95581085]
#  [ 3.98562339]
#  [ 4.02257975]
#  [ 4.09680005]
#  [ 4.22323598]
#  [ 4.24284306]]
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# #### 3. 'COMMIS'

# %%
df['COMMIS'].describe()
# Out:
# count      7109.000000
# mean     141005.726544
# std       78768.093718
# min        5055.000000
# 25%       84219.000000
# 50%      127628.000000
# 75%      184506.000000
# max      495405.000000
# Name: COMMIS, dtype: float64

# %%
#standardizing data
from sklearn.preprocessing import StandardScaler
sc_commis=StandardScaler()
saleprice_scaled = sc_commis.fit_transform(df['COMMIS'][:,np.newaxis]);
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-1.72608328]
#  [-1.72518183]
#  [-1.72198234]
#  [-1.71890982]
#  [-1.71480889]
#  [-1.71360273]
#  [-1.71219343]
#  [-1.71167288]
#  [-1.71108884]
#  [-1.70965415]]
#
# outer range (high) of the distribution:
# [[ 4.12823428]
#  [ 4.17602349]
#  [ 4.18699317]
#  [ 4.1928716 ]
#  [ 4.25061477]
#  [ 4.29507753]
#  [ 4.31671217]
#  [ 4.37921649]
#  [ 4.45586459]
#  [ 4.49959096]]
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# #### 4. 'INT_SQFT'

# %%
df['INT_SQFT'].describe()
# Out:
# count    7109.000000
# mean     1382.073006
# std       457.410902
# min       500.000000
# 25%       993.000000
# 50%      1373.000000
# 75%      1744.000000
# max      2500.000000
# Name: INT_SQFT, dtype: float64

# %%
#standardizing data
from sklearn.preprocessing import StandardScaler
sc_intSqft=StandardScaler()
saleprice_scaled = sc_intSqft.fit_transform(df['INT_SQFT'][:,np.newaxis]);
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-1.92853963]
#  [-1.92853963]
#  [-1.92853963]
#  [-1.92635326]
#  [-1.92635326]
#  [-1.92416688]
#  [-1.91979414]
#  [-1.91979414]
#  [-1.91760777]
#  [-1.9154214 ]]
#
# outer range (high) of the distribution:
# [[ 2.43108593]
#  [ 2.4332723 ]
#  [ 2.4332723 ]
#  [ 2.43545867]
#  [ 2.43545867]
#  [ 2.43545867]
#  [ 2.43764504]
#  [ 2.43983141]
#  [ 2.44201779]
#  [ 2.44420416]]
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# #### 5. 'N_ROOM'

# %%
df['N_ROOM'].describe()
# Out:
# count    7109.000000
# mean        3.688704
# std         1.019099
# min         2.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         6.000000
# Name: N_ROOM, dtype: float64

# %% [markdown]
# # Bivariate analysis

# %%
#bivariate analysis saleprice/grlivarea
var = 'REG_FEE'
data = pd.concat([df['SALES_PRICE'], df[var]], axis=1)
data.plot.scatter(x=var, y='SALES_PRICE');

# %% [markdown]
# # In the search for normality

# %%
"""['INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM',
       'QS_ROOMS', 'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE',
       'COMMIS', 'SALES_PRICE']"""
# Out:
# "['INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM',\n       'QS_ROOMS', 'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE',\n       'COMMIS', 'SALES_PRICE']"

# %%
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# ### 1.SALE PRICE

# %%
#histogram and normal probability plot
sns.distplot(df['SALES_PRICE'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['SALES_PRICE'], plot=plt)

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(5)
# Out:
#              Total  Percent
# SALES_PRICE      0      0.0
# COMMIS           0      0.0
# AREA             0      0.0
# INT_SQFT         0      0.0
# DATE_SALE        0      0.0

# %%
#applying log transformation
df['SALES_PRICE'] = np.log(df['SALES_PRICE'])

# %%
#histogram and normal probability plot
sns.distplot(df['SALES_PRICE'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['SALES_PRICE'], plot=plt)

# %% [markdown]
# ### 3. REG FEE

# %%
#histogram and normal probability plot
sns.distplot(df['REG_FEE'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['REG_FEE'], plot=plt)

# %%
df['REG_FEE']= np.log(df['REG_FEE'])

# %%
#histogram and normal probability plot
sns.distplot(df['REG_FEE'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['REG_FEE'], plot=plt)

# %% [markdown]
# ### 3.COMMIS

# %%
#histogram and normal probability plot
sns.distplot(df['COMMIS'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['COMMIS'], plot=plt)

# %%
df['COMMIS']=np.log(df['COMMIS'])

# %%
#histogram and normal probability plot
sns.distplot(df['COMMIS'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['COMMIS'], plot=plt)

# %% [markdown]
# ### 4. INT_SQFT

# %%
#histogram and normal probability plot
sns.distplot(df['INT_SQFT'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['INT_SQFT'], plot=plt)

# %%
df['INT_SQFT']=np.log(df['INT_SQFT'])

# %%
#histogram and normal probability plot
sns.distplot(df['INT_SQFT'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['INT_SQFT'], plot=plt)

# %% [markdown]
# ### 5.N_ROOMS

# %%
#histogram and normal probability plot
sns.distplot(df['N_ROOM'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['N_ROOM'], plot=plt)

# %% [markdown]
# ### 6. DIST_MAINROAD

# %%
df['DIST_MAINROAD'].describe()
# Out:
# count    7109.000000
# mean       99.603179
# std        57.403110
# min         0.000000
# 25%        50.000000
# 50%        99.000000
# 75%       148.000000
# max       200.000000
# Name: DIST_MAINROAD, dtype: float64

# %%
#histogram and normal probability plot
sns.distplot(df['DIST_MAINROAD'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['DIST_MAINROAD'], plot=plt)

# %%
numeric_data.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7109.000000  7109.000000  7109.000000
# mean      7.171315      99.603179     1.637029     1.213260     3.688704
# std       0.356701      57.403110     0.802845     0.409495     1.019099
# min       6.214608       0.000000     1.000000     1.000000     2.000000
# 25%       6.900731      50.000000     1.000000     1.000000     3.000000
# 50%       7.224753      99.000000     1.000000     1.000000     4.000000
# 75%       7.463937     148.000000     2.000000     1.000000     4.000000
# max       7.824046     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL      REG_FEE  \
# count  7109.000000  7109.000000  7109.000000  7109.000000  7109.000000
# mean      3.517471     3.507244     3.485300     3.503254    12.772258
# std       0.891972     0.897834     0.887266     0.525440     0.366954
# ...

# %% [markdown]
# ### ANOVA for categorical variables

# %%
#separate variables into new data frames
numeric_data = df.select_dtypes(include=[np.number])
cat_data = df.select_dtypes(exclude=[np.number])
print ("There are {} numeric and {} categorical columns in train data".format(numeric_data.shape[1],cat_data.shape[1]))
# Out:
# There are 12 numeric and 10 categorical columns in train data

# %%
numeric_data.columns
# Out:
# Index(['INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM',
#        'QS_ROOMS', 'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE',
#        'COMMIS', 'SALES_PRICE'],
#       dtype='object')

# %%
cat_data.columns
# Out:
# Index(['PRT_ID', 'AREA', 'DATE_SALE', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE'],
#       dtype='object')

# %%
cat = [f for f in df.columns if df.dtypes[f] == 'object']
def anova(frame):
    anv = pd.DataFrame()
    anv['features'] = cat
    pvals = []
    for c in cat:
           samples = []
           for cls in frame[c].unique():
                  s = frame[frame[c] == cls]['SALES_PRICE'].values
                  samples.append(s)
           pval = stats.f_oneway(*samples)[1]
           pvals.append(pval)
    anv['pval'] = pvals
    return anv.sort_values('pval')

cat_data['SALES_PRICE'] = df.SALES_PRICE.values
k = anova(cat_data) 
k['disparity'] = np.log(1./k['pval'].values) 
sns.barplot(data=k, x = 'features', y='disparity') 
plt.xticks(rotation=90) 
plt
# Out:
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\scipy\stats\stats.py:2925: RuntimeWarning: divide by zero encountered in double_scalars
#   msw = sswn / float(dfwn)
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in true_divide
# <module 'matplotlib.pyplot' from 'C:\\Users\\Jaadugar\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # Final Survey

# %% [markdown]
# ## Numerical Data

# %%
#create numeric plots
num = [f for f in df.columns if df.dtypes[f] != 'object']
nd = pd.melt(df, value_vars = num)
n1 = sns.FacetGrid (nd, col='variable', col_wrap=4, sharex=False, sharey = False)
n1 = n1.map(sns.distplot, 'value')
n1

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# def boxplot(x,y,**kwargs):
#             sns.boxplot(x=x,y=y)
#             x = plt.xticks(rotation=90)
#
# cat = [f for f in train.columns if train.dtypes[f] == 'object']
#
# p = pd.melt(train, id_vars='SalePrice', value_vars=cat)
# g = sns.FacetGrid (p, col='variable', col_wrap=2, sharex=False, sharey=False, size=5)
# g = g.map(boxplot, 'value','SalePrice')
# g

# %% [markdown]
# # Making Dataset

# %% [markdown]
# *NUMERICAL DATA*
# * 'SALES_PRICE'
# * 'REG_FEE'
# * 'COMMIS'
# * 'INT_SQFT'
# * 'N_ROOM'
#
# *CATEGORICAL DATA*
# * 'STREET'
# * 'PARK_FACIL'
# * 'UTILITY_AVAIL'

# %%
#df_new = df.filter(['REG_FEE','COMMIS','INT_SQFT','N_ROOM','STREET','PARK_FACIL','UTILITY_AVAIL','SALES_PRICE'], axis=1)

# %%
df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
df_new= df.drop(['PRT_ID','DATE_SALE','DATE_BUILD','DIST_MAINROAD'],axis=1)

# %%
df_new.head()
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  \
# 0  Karapakkam  6.911747        1.0         1.0       3  AbNormal        Yes
# 1  Anna Nagar  7.593878        2.0         1.0       5  AbNormal         No
# 2       Adyar  6.812345        1.0         1.0       3  AbNormal        Yes
# 3   Velachery  7.525640        3.0         2.0       5    Family         No
# 4  Karapakkam  7.111512        1.0         1.0       3  AbNormal        Yes
#
#     BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  \
# 0  Commercial        AllPub   Paved      A       4.0          3.9         4.9
# 1  Commercial        AllPub  Gravel     RH       4.9          4.2         2.5
# 2  Commercial           ELO  Gravel     RL       4.1          3.8         2.2
# 3      Others       NoSewr    Paved      I       4.7          3.9         3.6
# 4      Others        AllPub  Gravel      C       3.0          2.5         4.1
#
# ...

# %% [markdown]
# ### Dealing with categorical variable

# %% [markdown]
# #### STREET , PARK AND UTILITY_AVAIL

# %%
#convert categorical variable into dummy
df_new = pd.get_dummies(df_new)

# %%
df_new.head()
# Out:
#    INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  \
# 0  6.911747        1.0         1.0       3       4.0          3.9         4.9
# 1  7.593878        2.0         1.0       5       4.9          4.2         2.5
# 2  6.812345        1.0         1.0       3       4.1          3.8         2.2
# 3  7.525640        3.0         2.0       5       4.7          3.9         3.6
# 4  7.111512        1.0         1.0       3       3.0          2.5         4.1
#
#    QS_OVERALL    REG_FEE     COMMIS    ...      UTILITY_AVAIL_NoSewr   \
# 0       4.330  12.847927  11.880343    ...                          0
# 1       3.765  13.541234  12.624944    ...                          0
# 2       3.090  12.950611  11.430782    ...                          0
# 3       4.010  12.783587  11.252106    ...                          1
# 4       3.290  12.375815  11.212671    ...                          0
#
#    STREET_Gravel  STREET_No Access  STREET_Paved  MZZONE_A  MZZONE_C  \
# ...

# %%
X = df_new.drop(['SALES_PRICE'],axis=1).values
y = df_new['SALES_PRICE']

# %%
len(df_new.columns)
# Out:
# 41

# %%
train_col=df_new.columns

# %% [markdown]
# # Modeling

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## 1. XGBOOST

# %%
import xgboost as xgb
regr = xgb.XGBRegressor(colsample_bytree=0.2,
                       gamma=0.0,
                       learning_rate=0.05,
                       max_depth=6,
                       min_child_weight=1.5,
                       n_estimators=10000,
                       reg_alpha=0.9,
                       reg_lambda=0.6,
                       subsample=0.2,
                       seed=42,
                       silent=1)

# %%
regr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.2,
#        gamma=0.0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1.5, missing=None, n_estimators=10000, nthread=-1,
#        objective='reg:linear', reg_alpha=0.9, reg_lambda=0.6,
#        scale_pos_weight=1, seed=42, silent=1, subsample=0.2)

# %%
from sklearn.metrics import mean_squared_error
def rmse(y_test,y_pred):
      return np.sqrt(mean_squared_error(y_test,y_pred))

# run prediction on training set to get an idea of how well it does
y_pred = regr.predict(X_test)
print("XGBoost score on test set: ", rmse(y_test, y_pred))
# Out:
# XGBoost score on test set:  0.0315425541253

# %% [markdown]
# ## 2. Lasso model

# %%
from sklearn.linear_model import Lasso

#found this best alpha through cross-validation
best_alpha = 0.00099

regr_lasso = Lasso(alpha=best_alpha, max_iter=50000)
regr_lasso.fit(X_train, y_train)

# run prediction on the training set to get a rough idea of how well it does
y_pred = regr_lasso.predict(X_test)
print("Lasso score on test set: ", rmse(y_test, y_pred))
# Out:
# Lasso score on test set:  0.048671651995

# %% [markdown]
# ## 3. Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.preprocessing import StandardScaler

np.random.seed(10)

#create Model
#define base model
def base_model():
     model = Sequential()
     model.add(Dense(20, input_dim=40, init='normal', activation='relu'))
     model.add(Dense(10, init='normal', activation='relu'))
     model.add(Dense(1, init='normal'))
     model.compile(loss='mean_squared_error', optimizer = 'adam')
     return model

seed = 7
np.random.seed(seed)

scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.fit_transform(X_test)

#keras_label = label_df.as_matrix()
clf = KerasRegressor(build_fn=base_model, nb_epoch=5, batch_size=5,verbose=0)
clf.fit(X_train,y_train)
# Out:
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, input_dim=40, activation="relu", kernel_initializer="normal")`
#   if sys.path[0] == '':
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, activation="relu", kernel_initializer="normal")`
#   del sys.path[0]
# C:\Users\Jaadugar\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="normal")`

# %%
#make predictions and create the submission file 
kpred = clf.predict(X_test) 
kpred = np.exp(kpred)
print("Neural Net on test set: ", rmse(y_test, kpred))
# Out:
# Neural Net on test set:  11424740.1216

# %% [markdown]
# ## 4. Random Forrest

# %%
# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regr_randFor = RandomForestRegressor(n_estimators = 1000, random_state = 0)

# %%
regr_randFor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# run prediction on the training set to get a rough idea of how well it does
y_pred = regr_randFor.predict(X_test)
print("Random Forest on test set: ", rmse(y_test, y_pred))
# Out:
# Random Forest on test set:  0.0667516373794

# %% [markdown]
# ## 5.SVM Regressor

# %%
# Fitting SVR to the dataset
from sklearn.svm import SVR
regr_svm = SVR(kernel = 'rbf')
regr_svm.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting a new result
y_pred = regr_svm.predict(X_test)
print("SVM on test set: ", rmse(y_test, y_pred))
# Out:
# SVM on test set:  0.0548418798294

# %% [markdown]
# ## 6. Light GMB

# %%
import lightgbm as lgb

# %%
# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'rms'},
    'num_leaves': 1000,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

print('Start training...')
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=500,
                valid_sets=lgb_eval)
# Out:
# Start training...
# [1]	valid_0's l2: 0.110833
# [2]	valid_0's l2: 0.100663
# [3]	valid_0's l2: 0.0917134
# [4]	valid_0's l2: 0.0834057
# [5]	valid_0's l2: 0.0758992
# [6]	valid_0's l2: 0.0691063
# [7]	valid_0's l2: 0.0630857
# [8]	valid_0's l2: 0.0576297
# [9]	valid_0's l2: 0.0525126
# [10]	valid_0's l2: 0.0479783
# [11]	valid_0's l2: 0.043856
# [12]	valid_0's l2: 0.0401629
# [13]	valid_0's l2: 0.0367948
# [14]	valid_0's l2: 0.033823
# [15]	valid_0's l2: 0.0311099
# [16]	valid_0's l2: 0.0285675
# [17]	valid_0's l2: 0.0262726
# [18]	valid_0's l2: 0.0241935
# [19]	valid_0's l2: 0.0222658
# [20]	valid_0's l2: 0.0206485
# [21]	valid_0's l2: 0.0191164
# [22]	valid_0's l2: 0.0176939
# [23]	valid_0's l2: 0.01645
# [24]	valid_0's l2: 0.0152764
# [25]	valid_0's l2: 0.0142654
# [26]	valid_0's l2: 0.0133173
# [27]	valid_0's l2: 0.0124849
# [28]	valid_0's l2: 0.011696
# [29]	valid_0's l2: 0.0109937
# [30]	valid_0's l2: 0.0103647
# [31]	valid_0's l2: 0.00974736
# [32]	valid_0's l2: 0.0091975
# ...

# %%
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
print("LightGMB on test set: ", rmse(y_test, y_pred))
# Out:
# LightGMB on test set:  0.0410201080465

# %% [markdown]
# # PREDICTING THE TEST RESULTS

# %%
df=pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P05996    Chrompet       958  13-11-2009            185          1
# 1  P09294  Anna Nagar      1807  29-01-2007            108          2
# 2  P03807  Karapakkam      1658  07-01-2011             59          2
# 3  P00539  Anna Nagar      1592  22-01-2014            102          1
# 4  P01448    Chrompet       857  01-05-2012             62          1
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL   ...   BUILDTYPE UTILITY_AVAIL  \
# 0           1       3  AbNormal         No   ...      Others       NoSewr
# 1           1       5   AdjLand        Yes   ...      Others        NoSeWa
# 2           2       4   AdjLand         No   ...      Others        NoSeWa
# 3           1       4  AbNormal        Yes   ...      Others        AllPub
# 4           1       3    Family         No   ...       House           ELO
#
#       STREET MZZONE QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  \
# ...

# %%
#Removing Duplicates

# %%
for i in range(len(df['AREA'])):
    if (df['AREA'][i]=='Chrompt') or (df['AREA'][i]=='Chrmpet') or (df['AREA'][i]=='Chrompet') or (df['AREA'][i]=='Chormpet'):
        df.set_value(i,'AREA','Chrompet')
    if (df['AREA'][i]=='Ana Nagar') or (df['AREA'][i]=='Ann Nagar'):
        df.set_value(i,'AREA','Anna Nagar')
    if (df['AREA'][i]=='TNagar'):
        df.set_value(i,'AREA','T Nagar')
    if (df['AREA'][i]=='Adyr'):
        df.set_value(i,'AREA','Adyar')
    if (df['AREA'][i]=='KKNagar'):
        df.set_value(i,'AREA','KK Nagar')
    if (df['AREA'][i]=='Velechery') or (df['AREA'][i]=='Velchery'):
        df.set_value(i,'AREA','Velachery')
    if (df['AREA'][i]=='Karapakm') or (df['AREA'][i]=='Karapakam'):
        df.set_value(i,'AREA','Karapakkam')

# %%
for i in range(len(df)):
    if (df['SALE_COND'][i]=='Adj Land'):
        df.set_value(i,'SALE_COND','AdjLand')
    if (df['SALE_COND'][i]=='Ab Normal'):
        df.set_value(i,'SALE_COND','AbNormal') 
    if (df['SALE_COND'][i]=='Partiall') or (df['SALE_COND'][i]=='PartiaLl'):
        df.set_value(i,'SALE_COND','Partial')

# %%
for i in range(len(df)):
    if (df['PARK_FACIL'][i]=='Noo'):
        df.set_value(i,'PARK_FACIL','No')

# %%
for i in range(len(df)):
    if (df['BUILDTYPE'][i]=='Other'):
        df.set_value(i,'BUILDTYPE','Others')
    if (df['BUILDTYPE'][i]=='Comercial') or (df['BUILDTYPE'][i]=='Commercil'):
        df.set_value(i,'BUILDTYPE','Commercial')

# %%
for i in range(len(df)):
    if (df['UTILITY_AVAIL'][i]=='All Pub'):
        df.set_value(i,'UTILITY_AVAIL','AllPub')

# %%
for i in range(len(df)):
    if (df['STREET'][i]=='Pavd'):
        df.set_value(i,'STREET','Paved')
    if (df['STREET'][i]=='NoAccess'):
        df.set_value(i,'STREET','No Access')

# %%
#Normality

# %%
df['REG_FEE']= np.log(df['REG_FEE'])

# %%
df['COMMIS']=np.log(df['COMMIS'])

# %%
df['INT_SQFT']=np.log(df['INT_SQFT'])

# %%
df.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  2925.000000    2925.000000  2925.000000  2925.000000  2925.000000
# mean      7.182915      97.096068     1.652308     1.220513     3.723077
# std       0.347760      58.477193     0.787513     0.414663     0.989979
# min       6.214608       0.000000     1.000000     1.000000     2.000000
# 25%       6.913737      46.000000     1.000000     1.000000     3.000000
# 50%       7.273786      95.000000     1.000000     1.000000     4.000000
# 75%       7.463937     147.000000     2.000000     1.000000     4.000000
# max       7.824046     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL      REG_FEE  \
# count  2925.000000  2925.000000  2925.000000  2906.000000  2925.000000
# mean      3.517504     3.476410     3.503282     3.505382    12.789181
# std       0.885223     0.890613     0.895900     0.525879     0.355492
# ...

# %%
df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS'],
#       dtype='object')

# %%
df_new=df.drop(['PRT_ID','DATE_SALE','DATE_BUILD','DIST_MAINROAD'],axis=1)

# %%
df.fillna(df.mean(), inplace=True);

# %%
#convert categorical variable into dummy
df_new = pd.get_dummies(df_new)

# %%
len(df_new.columns)
# Out:
# 40

# %%
test_col=df_new.columns

# %%
test_col
# Out:
# Index(['INT_SQFT', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'AREA_Adyar', 'AREA_Anna Nagar', 'AREA_Chrompet', 'AREA_KK Nagar',
#        'AREA_Karapakkam', 'AREA_T Nagar', 'AREA_Velachery',
#        'SALE_COND_AbNormal', 'SALE_COND_AdjLand', 'SALE_COND_Family',
#        'SALE_COND_Normal Sale', 'SALE_COND_Partial', 'PARK_FACIL_No',
#        'PARK_FACIL_Yes', 'BUILDTYPE_Commercial', 'BUILDTYPE_House',
#        'BUILDTYPE_Others', 'UTILITY_AVAIL_AllPub', 'UTILITY_AVAIL_ELO',
#        'UTILITY_AVAIL_NoSeWa', 'UTILITY_AVAIL_NoSewr ', 'STREET_Gravel',
#        'STREET_No Access', 'STREET_Paved', 'MZZONE_A', 'MZZONE_C', 'MZZONE_I',
#        'MZZONE_RH', 'MZZONE_RL', 'MZZONE_RM'],
#       dtype='object')

# %%
train_col
# Out:
# Index(['INT_SQFT', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'AREA_Adyar', 'AREA_Anna Nagar', 'AREA_Chrompet',
#        'AREA_KK Nagar', 'AREA_Karapakkam', 'AREA_T Nagar', 'AREA_Velachery',
#        'SALE_COND_AbNormal', 'SALE_COND_AdjLand', 'SALE_COND_Family',
#        'SALE_COND_Normal Sale', 'SALE_COND_Partial', 'PARK_FACIL_No',
#        'PARK_FACIL_Yes', 'BUILDTYPE_Commercial', 'BUILDTYPE_House',
#        'BUILDTYPE_Others', 'UTILITY_AVAIL_AllPub', 'UTILITY_AVAIL_ELO',
#        'UTILITY_AVAIL_NoSeWa', 'UTILITY_AVAIL_NoSewr ', 'STREET_Gravel',
#        'STREET_No Access', 'STREET_Paved', 'MZZONE_A', 'MZZONE_C', 'MZZONE_I',
#        'MZZONE_RH', 'MZZONE_RL', 'MZZONE_RM'],
#       dtype='object')

# %%
for i in range(len(train_col)):
    temp=train_col[i]
    x=0
    for j in range(len(test_col)):
        if temp == test_col[j] :
            x=1
            break
    if x==0:
        print(train_col[i])
# Out:
# SALES_PRICE

# %%
X_test=df_new.values

# %%
#using xgb

# %%
y_pred = regr.predict(X_test)
y_pred = np.exp(y_pred)

# %%
result=pd.read_csv('result.csv')

# %%
result.head()
# Out:
#    PRT_ID
# 0  P05996
# 1  P09294
# 2  P03807
# 3  P00539
# 4  P01448

# %%
result['SALES_PRICE']=y_pred
result.to_csv('xgb.csv')
